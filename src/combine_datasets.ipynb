# %%
# Import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# Load data
df_activity = pd.read_csv('../data/boulders/AttendanceHistorys_clean.csv', sep=';')
df_account = pd.read_csv('../data/boulders/Medlemsdata_clean.csv', sep=';')
df_dmi = pd.read_csv('../data/dmi/dmi.csv', sep=';')
# Out:
# /tmp/ipykernel_56694/2637369942.py:2: DtypeWarning: Columns (6,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_activity = pd.read_csv('../data/boulders/AttendanceHistorys_clean.csv', sep=';')

# %%
# Join datasets
df_main = pd.merge(df_activity, df_account, on=)
# Out:
#                  Timestamp  Middeltemperatur  Maksimumtemperatur  \
# 0      2021-01-01 00:00:00               1.7                 1.9
# 1      2021-01-01 01:00:00               1.8                 2.0
# 2      2021-01-01 02:00:00               1.9                 2.1
# 3      2021-01-01 03:00:00               2.0                 2.2
# 4      2021-01-01 04:00:00               2.1                 2.3
# ...                    ...               ...                 ...
# 25289  2023-12-31 19:00:00               4.5                 4.7
# 25290  2023-12-31 20:00:00               4.6                 4.7
# 25291  2023-12-31 21:00:00               4.6                 4.7
# 25292  2023-12-31 22:00:00               4.7                 4.9
# 25293  2023-12-31 23:00:00               4.7                 4.8
#
#        Minimumtemperatur
# 0                    1.4
# 1                    1.6
# 2                    1.7
# 3                    2.0
# 4                    2.0
# ...                  ...
# ...
